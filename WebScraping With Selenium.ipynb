# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC 
from bs4 import BeautifulSoup
f = open("config/Credentials.txt", "r")
Txt = str.split(f.read(),"\n")

# %%
url= 'https://www.classmarker.com'
#create a new chrome session
driver = webdriver.Chrome("D:\Basic Software\chromedriver_win32/chromedriver.exe")
# driver.implicity_wait(30)
driver.get(url)
username=driver.find_element_by_id('un') #$$$$$
username.send_keys(Txt[0])
password=driver.find_element_by_id('pw')
password.send_keys(Txt[1])
submit_button = driver.find_elements_by_xpath("//input[@name='login' and @value='Login']")[0]
submit_button.click()
Results_Button = driver.find_elements_by_xpath("//*[contains(text(), 'Results')]")
Results_Button[5].click()
# wait = WebDriverWait(driver,30)
# Results_Button = wait.until(EC.element_to_be_clickable((By.XPATH, "//button[contains(text(),'Results') and @class='btn btn-results']")))
# find_element_by_class_name('btn btn-results')
tutorial_soup = BeautifulSoup(driver.page_source, 'html.parser')
print(tutorial_soup.prettify)
print(Results_Button)
# Results_Button[5].click()
# Results_Button = driver.find_elements_by_xpath("//href='/a/results/tests/test/rgusers/?test_id=1190186&amp;rg_id=457851'")[0]
# Results_Button.click()
# python_button.click()#click $$$$$ link
# Out:
# <bound method Tag.prettify of <html lang="en"><head>
# <meta charset="utf-8"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <title>ClassMarker - Overall Test results</title>
# <script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-791178814"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'AW-791178814'); </script>
# <link href="/js3/css/smoothness/jquery-ui-1.12.1.custom.min.css" rel="stylesheet" type="text/css"/>
# <link href="/css3/cm.css?v=242" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css3/quiz.css?v=242" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css3/cmbbcode.css?v=242" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
File_object = open(r"Result_Page","w")
# File_object.write(tutorial_soup.prettify)
strs = tutorial_soup.prettify

# %%
str(strs)
# Out:
# '<bound method Tag.prettify of <html lang="en"><head>\n<meta charset="utf-8"/>\n<link href="/favicon.ico" rel="shortcut icon"/>\n<title>ClassMarker - Group Test results</title>\n<script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-791178814"></script> <script> window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag(\'js\', new Date()); gtag(\'config\', \'AW-791178814\'); </script>\n<link href="/js3/css/smoothness/jquery-ui-1.12.1.custom.min.css" rel="stylesheet" type="text/css"/>\n<link href="/css3/cm.css?v=242" media="screen" rel="stylesheet" type="text/css"/>\n<link href="/css3/quiz.css?v=242" media="screen" rel="stylesheet" type="text/css"/>\n<link href="/css3/cmbbcode.css?v=242" media="screen" rel="stylesheet" type="text/css"/>\n<link href="/js3/featherlight/featherlight.css" rel="stylesheet" type="text/css"/>\n<script>\n\t\tvar audio_video_warning = \'\';\n\t</script>\n<link crossorigin="anonymous" href="https://cdnjs.cloudflar
# ...

# %%
f = open("config/Credentials.txt", "r")
Txt = f.read()

# %%
str.split(Txt,"\n")
# Out:
# 'rahul.phutela'
